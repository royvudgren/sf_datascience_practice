# %% [markdown]
# # **Работа с API**

# %% [markdown]
# Многие крупные сайты предоставляют доступ к так называемым **API** (англ. Application Programming Interface, рус. Интерфейс Прикладного Программирования).
#
# **API** — это специальные разделы сайта, где информацию можно получать **без разметки**, а **формат запросов и ответов зафиксирован**. API созданы для того, чтобы облегчить взаимодействие с сайтом для сторонних разработчиков.
#
# Рассмотрим на примере социальной сети ВКонтакте особенности API, характерные для более крупных сайтов.

# %% [markdown]
# ##### **КЛЮЧ АВТОРИЗАЦИИ**
# ***
# Для того чтобы начать работать с API, обычно необходимо получить сервисный ключ авторизации — **токен**.
#
# **Токен** — это средство *идентификации* пользователя или отдельного сеанса работы *в компьютерных сетях и приложениях*. Различают *программные* и *аппаратные* токены.
# Мы будем использовать программный токен, который обычно представляет собой зашифрованную последовательность символов, позволяющую точно идентифицировать объект и определить уровень его привилегий. Он генерируется системой авторизации и привязывается к конкретному сеансу работы, клиенту сети или пакету данных.
#
# Сервисный токен для API ВКонтакте для нашей задачи создаётся вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.

# %% [markdown]
# ##### **ЗАПРОСЫ ИЗ БРАУЗЕРА**
# ***
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Сделаем наш первый запрос из браузера.
#
# Перейдите по следующей ниже ссылке в браузере, подставив вместо слова *TOKEN* ваш персональный сервисный ключ доступа (токен), полученный на предыдущем шаге:
#
# **https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=TOKEN**
#
# Итак, мы сделали GET-запрос к API ВКонтакте, который состоит из следующих элементов:
#
# * https://api.vk.com/method — домен и URL запроса API; обычно не меняется;
# * users.get — название метода, который отдаёт определённый отчёт, в нашем случае это метод для получения информации о пользователе;
# * user_id и v — параметры запроса: идентификатор пользователя, о котором хотим получить информацию (в нашем примере мы запрашиваем информацию о первом пользователе), и номер версии API;
# * token — токен, который выдаётся только пользователям, имеющим право просматривать определённые данные, например показания счётчиков Яндекс.Метрики вашего проекта; на все остальные запросы без корректного токена система отвечает отказом.
#
# Если мы обратимся к [**документации метода users.get**](https://vk.com/dev/users.get), то увидим, что в ней описано множество других параметров, которые можно получить о пользователе (дата рождения, пол, родной город и другие) — словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал).
#
# Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):
#
# **https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=TOKEN**

# %% [markdown]
# ##### **ЗАПРОС К API ИЗ КОДА**
# ***
# Продолжаем пользоваться всё той же библиотекой requests.

# %%
import requests # Импортируем модуль requests
from pprint import pprint
import time # Импортируем модуль time

# %%
token = 'dfc65ed2dfc65ed2dfc65ed21fdfba1207ddfc6dfc65ed2bda5c5957a7f5bc7684658c4' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}

# %% [markdown]
# Мы получили строку в JSON-формате, которую можно преобразовать в словарь с помощью метода **json()**, после чего можно с лёгкостью обращаться к различным полям.
#
# Словари нагляднее выводить с помощью функции **pprint()**, которую мы уже использовали ранее:

# %%
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %% [markdown]
# По ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один элемент. Извлечём его:

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %% [markdown]
# Метод **users.get()** позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр **user_ids** и передавать id **через запятую в строковом формате**. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.

# %%
# Формируем строку, содержащую информацию о поле id первых трёх пользователей
ids = ",".join(map(str, range(1, 4)))
# Формируем строку параметров
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'}
# Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь
# и выводим на экран его содержимое, используя функцию pprint()
pprint(requests.get(url, params=params).json())
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %%
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. 
# Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
# В ответе укажите число, округлив до двух знаков после точки-разделителя
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}
dict_of_users = requests.get(url, params=params).json()

have_sex=0
women=0
for i in range(0,500):
    sex = dict_of_users['response'][i]['sex']
    if sex==1:
        women+=1
        have_sex+=1
    if sex==2:
        have_sex+=1
women_share = round(women/have_sex,2)
print(women_share)
# Out:
# 0.49

# %% [markdown]
# ##### **СБОР ИНФОРМАЦИИ ИЗ ГРУПП**
# ***
# В одном из предыдущих юнитов в качестве примера мы собрали информацию о небольшом количестве пользователей. Теперь перейдём к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:
#
# * не учитываются все особенности вашего проекта;
# * используется фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
# * не всегда бесплатны и вряд ли позволят работать с большими объёмами данных.
#
# Теперь мы научимся считать произвольные метрики групп, собирая данные из API и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# * ограничение на количество вызовов в единицу времени;
# * ограничение на количество выгружаемых строк за один запрос.
#
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk социальной сети ВКонтакте.
#
# Обратимся к [**документации**](https://vk.com/dev/groups), чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод **groups.getMembers**.
#
# Согласно документации, обязательным параметром данного метода является **group_id** — идентификатор или короткое имя группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
#print(data) # Выводим содержимое переменной data на экран
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром **offset** (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину **count**.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по пять за раз:

# %%
import requests # Импортируем модуль requests
token = 'dfc65ed2dfc65ed2dfc65ed21fdfba1207ddfc6dfc65ed2bda5c5957a7f5bc7684658c4' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print(f'Выгружаю {count} пользователей с offset = {offset}')   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %%
# Сравним списки, полученные двумя способами:
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# Так как результат сравнения — True, списки идентичны. Значит, второй способ работает корректно. Теперь мы можем получить данные обо всех пользователях, выставив count = 1000 и max_count = data['response']['count'].

# %% [markdown]
# ##### **ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ**
# ***
# В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой **time** и методом **sleep**, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ##### **ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ**
# ***
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 1000 сообщений в новостной ленте.
#
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 484,
#               'items': [{'attachments': [{'type': 'video',
#                                           'video': {'access_key': '5bd99da508c4b69bd5',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1650036655,
#                                                     'description': '',
#                                                     'duration': 30,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456241782,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_x',
#                                                     'repeat': 1,
#                                                     'title': 'VK Звонки',
#                                                     'track_code': 'video_8f278775tb2G3mpQ4486jmT3jUo6308j2Ity8OmZKilwvPf_V22FnJjcbTfgjzCKYJiLfwztexLvs0D0nvhGRXA',
#                                                     'views': 262995,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 377,
#                                       'groups_can_post': True},
#                          'date': 1650036838,
#                          'from_id': -22822305,
#                          'hash': 'gVQZBtobU3LADAIKew',
#                          'id': 1294102,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 865,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 282, 'user_reposted': 0},
#                          'text': 'Представляем мобильное приложение VK Звонков '
#                                  '— со всеми функциями для безлимитных '
#                                  'онлайн-конференций. Оно уже доступно в App '
#                                  'Store (vk.cc/ccNmFQ) и Google Play '
#                                  '(vk.cc/ccNmMx). А в браузере попробуйте '
#                                  'веб-версию: calls.vk.com. \n'
#                                  '\n'
#                                  'Приложение полностью бесплатное, и все '
#                                  'возможности VK Звонков — в быстром доступе. '
#                                  'Подключиться к конференции по ссылке можно '
#                                  'даже без профиля. Время разговора и '
#                                  'количество участников не ограничены: '
#                                  'собирайте друзей, подписчиков, слушателей '
#                                  'онлайн-курса или всю команду большого '
#                                  'проекта.\n'
#                                  '\n'
#                                  'Планируете встречи заранее? Скоро это можно '
#                                  'будет удобно делать в VK Звонках. Можно '
#                                  'будет создать конференцию, поставить '
#                                  'напоминание в календаре и отправить ссылку '
#                                  'участникам — по почте или в любом '
#                                  'мессенджере. В нужное время звонок станет '
#                                  'активным, и собеседники смогут '
#                                  'присоединиться. Для регулярных встреч можно '
#                                  'сделать звонок повторяющимся. \n'
#                                  '\n'
#                                  'Звонить и принимать вызовы всё так же можно '
#                                  'на других платформах: в приложении и '
#                                  'веб-версии ВКонтакте, десктопном приложении '
#                                  'VK Звонков.',
#                          'views': {'count': 278826}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '6a468035ea9e037e72',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 14,
#                                                     'date': 1649850595,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=0&type=39&tkn=7HqIqxaPjCgrOHlmhSLPHJZNwzc',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=0&type=39&tkn=7HqIqxaPjCgrOHlmhSLPHJZNwzc&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=0&type=39&tkn=7HqIqxaPjCgrOHlmhSLPHJZNwzc&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=0&type=39&tkn=7HqIqxaPjCgrOHlmhSLPHJZNwzc&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=0&type=39&tkn=7HqIqxaPjCgrOHlmhSLPHJZNwzc&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456239064,
#                                                     'owner_id': -207536086,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=5&type=39&tkn=mThtaFL84Xwc76D0Z6uniX6Pt8M&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=5&type=39&tkn=mThtaFL84Xwc76D0Z6uniX6Pt8M&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=5&type=39&tkn=mThtaFL84Xwc76D0Z6uniX6Pt8M&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=2492591835762&idx=5&type=39&tkn=mThtaFL84Xwc76D0Z6uniX6Pt8M&fn=vid_x',
#                                                     'title': 'NeuroHD 2.0',
#                                                     'track_code': 'video_53448482LiwYV5x0bRUqo9MwDGVBoWiOp3lg1spJKfe182-xFfkUCgdWnHYHFy6q2DJmaXSXWr2eSVbizj5Im9nz',
#                                                     'views': 308552,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 204,
#                                       'groups_can_post': True},
#                          'date': 1649929834,
#                          'from_id': -22822305,
#                          'hash': 'F0NbeF0PBAGnCNK_cw',
#                          'id': 1293458,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 852,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 208, 'user_reposted': 0},
#                          'text': 'В VK Видео — обновление для любителей '
#                                  'высокого качества. Теперь в роликах можно '
#                                  'автоматически повышать разрешение до 720p и '
#                                  'частоту кадров до 60 FPS, а также убирать '
#                                  'шумы и дрожание кадра. \n'
#                                  '\n'
#                                  'Весь секрет — в собственной нейросетевой '
#                                  'технологии NeuroHD, у которой нет аналогов '
#                                  'на других крупных видеоплатформах. Чтобы '
#                                  '[https://vk.com/video-207536086_456239066|улучшить] '
#                                  'видео, нейросеть анализирует объекты в нём, '
#                                  'а потом достраивает дополнительный кадр. Так '
#                                  'ролик '
#                                  '[https://vk.com/video-207536086_456239065|становится] '
#                                  'более плавным и приобретает эффект '
#                                  'стабилизации: можно с комфортом смотреть '
#                                  'спортивные соревнования или давние '
#                                  'любительские ролики. \n'
#                                  '\n'
#                                  'Чтобы сделать ролик качественнее, достаточно '
#                                  'выбрать опцию автоматического улучшения при '
#                                  'загрузке видео через десктопную версию '
#                                  'ВКонтакте. Рекомендуем попробовать!',
#                          'views': {'count': 287371}},
#                         {'attachments': [{'photo': {'access_key': '4e67d07fd8ed8a2e35',
#                                                     'album_id': -7,
#                                                     'date': 1649761400,
#                                                     'id': 457331013,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/-5fT_tGS1LKb_1OoZ5fXjnr-dYqYbCh0RaTIzkH9AsKMzLPY2DtL3DCrrEcaLjSI0rrQtEokm57D0LgqeL9TiEy7.jpg?size=75x75&quality=95&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/tyq3zaMlvqxP_3PfCF6s5jGgy-v2avLU-YPkZf4klFfosru1gt-0Nna0TfIPvCTbuaGnwo50RkuIzq6bVpY2Myls.jpg?size=130x130&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/tsQx6G9fNJ_fkiIev5zn-h9FAnmth91Ob8Z8YWgRF7eHT9-vzusqLHeGofozM-a1L4aemhtx-fi-InsN68uiw8GI.jpg?size=604x604&quality=95&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/C5SQS-9ekbn-a-X7ee45PIKBtPlHyt3zATI8XpHVua7MoHQr9BT3C2JGFfA9HugaC8gJ7Tmc2gLVP7YzyXeasd_H.jpg?size=807x807&quality=95&type=album',
#                                                                'width': 807},
#                                                               {'height': 1200,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/id6JGkUIpCVFjKBpyeKbHpY-kYiwpD0gNUVxOsVvwoO_8P00ECu_I6dBQlHyFq6vq4RUevoErwdrQtnYtpBjA_87.jpg?size=1200x1200&quality=95&type=album',
#                                                                'width': 1200},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/tyq3zaMlvqxP_3PfCF6s5jGgy-v2avLU-YPkZf4klFfosru1gt-0Nna0TfIPvCTbuaGnwo50RkuIzq6bVpY2Myls.jpg?size=130x130&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/zISjVKjnp1-dlJKxIV6JuZOPLeL9BIlvd2ZnRHhoKgmo-Gz-TU1KCji0An3Yhy7w5n4-2YAmojcW6rI0tIGzkxP6.jpg?size=200x200&quality=95&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/ddDPcFIOAW0wT2ql5LyEOrZAtshDWhwoux6B5u0dN54jFYGPInCUxu4XZUK4jN3NKn-4N2RnHB-WQ4sHqp05jhKE.jpg?size=320x320&quality=95&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-70.userapi.com/s/v1/ig2/jdHtWmtLrhEfnWhppntibvXlJvBqyQKIsABFTEKdxQVnhbB_2MifZ6abCjsyIUodsyS5nZgJLf3TBqiPQDWrW2nD.jpg?size=510x510&quality=95&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'},
#                                          {'doc': {'access_key': 'ZYxZRt0Ilw3jL023tVGIUjfWN4KIKCkMOyHM4JNg440',
#                                                   'date': 1649764743,
#                                                   'ext': 'pdf',
#                                                   'id': 630141698,
#                                                   'owner_id': 2160979,
#                                                   'size': 135743,
#                                                   'title': 'Правила проведения '
#                                                            'Акции '
#                                                            'Мультивселенная '
#                                                            'ВКонтакте.pdf',
#                                                   'type': 1,
#                                                   'url': 'https://vk.com/doc2160979_630141698?hash=4Wc6NEw0pQPZzMYzZy1MRY190DwuhDBE0263JWjHA7w&dl=GA:1650700116:hTc2yFB4D66zBJdcVMDN0h1eS0qrdIDWfrNxy8HdJPg&api=1&no_preview=1'},
#                                           'type': 'doc'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1422,
#                                       'groups_can_post': True},
#                          'date': 1649757486,
#                          'edited': 1649774421,
#                          'from_id': -22822305,
#                          'hash': '2PXC1I2GhsRK43wUkA',
#                          'id': 1292560,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 4966,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 1276, 'user_reposted': 0},
#                          'text': 'В мультивселенной ВКонтакте открылись '
#                                  'порталы — найдите их все! Отмечаем День '
#                                  'космонавтики большим межпространственным '
#                                  'приключением.\n'
#                                  '\n'
#                                  '🌍 Ищите в разных разделах ВКонтакте '
#                                  'космические пасхалки, исследуйте миры наших '
#                                  'сервисов и получайте звёздные призы. За '
#                                  'шесть пасхалок вы получите скидку 75% на '
#                                  'анимированный стикерпак или 70% на '
#                                  'статичный. Акция продлится до 17 апреля. '
#                                  'Полный текст правил — в прикреплённом '
#                                  'документе.\n'
#                                  '\n'
#                                  '🌠 Отправляйтесь в путешествие с '
#                                  '[https://vk.com/steps#loyalty|«Шагами»]: они '
#                                  'запускают '
#                                  '[https://vk.com/@vkhealth-pravila-provedeniya-reklamnoi-akcii-kosmicheskii-marafon|космический '
#                                  'марафон], который продлится до 12 мая. '
#                                  'Гуляйте и открывайте неизведанные планеты, а '
#                                  'ещё получайте монеты, награды, уникальные '
#                                  'эмодзи-статусы и билеты на розыгрыш '
#                                  'суперпризов. Вас ждут промокоды на покупки в '
#                                  'Ozon и многое другое.\n'
#                                  '\n'
#                                  '⚡ VK Музыка собрала космический плейлист. '
#                                  'Слушайте тематические треки и участвуйте в '
#                                  'розыгрыше годовой подписки VK Combo до 18 '
#                                  'апреля. Тут рассказываем подробнее про '
#                                  'акцию: vk.cc/ccFYQH.\n'
#                                  '\n'
#                                  '🔮 Ещё можно задать настроение разговорам в '
#                                  'VK Звонках со специальными фонами, примерить '
#                                  'космические маски в историях и клипах. '
#                                  'Подарки приготовил и VK Чекбэк, общий '
#                                  'призовой фонд — 100\u2009000 рублей. Принять '
#                                  'участие в розыгрыше можно до 26 апреля, '
#                                  'подробнее здесь: vk.cc/buterbek.',
#                          'views': {'count': 748483}},
#                         {'attachments': [{'photo': {'access_key': '60cde12f689dd7054f',
#                                                     'album_id': -7,
#                                                     'date': 1649349731,
#                                                     'id': 457330956,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1291831,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/KuNtGZ3Qq1NiviTuv1wtUuYcvDQKsKm-ng2yx07LI0fnbAflXOEAU-Djj3IrNhI_bji5uhZot1fYVbKO1uUu1tqo.jpg?size=75x75&quality=95&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/Tsysrq3Y-zSkjevVBt3OyVJUtBmMLUw0xhlJ36IU-CoWKRSwRwuSmJjUVL1rw6hEPZe6eUNHE0dijBxzD7b-HlGK.jpg?size=130x130&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/QNvUuK9hOZ1RNIyLzDljYm4CG4H2doYgDuE4Ibj9W3SOvR4tK911v9KJWjOKuNzAeCbw_vXLv3ucwy7EcntpQ1Mm.jpg?size=604x604&quality=95&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/rApdUTEtBRIXOEuwmqfBIieZ1SRX5mqOZ0SiZWrdi_xvgQBq7ISE_a6cE1eYF8GUPaUVx5-iBbuGExmdX-sBmc8E.jpg?size=807x807&quality=95&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/qKTsm4Ra2cFWmK45MoYj6fdjRBm1MUqfEf1kDjJztQbhIsH-OBqXFejJYnMVUXzsiNIxcDrQJfsPl1maz2BFRvFx.jpg?size=1280x1280&quality=95&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1852,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/CgDK6iB7SDj1DbMjhvYgMlFN0NsuDoMH02l-Urap3Y9YInqCDBMRfAqudKQCdtT4zW9RLGhUlSLlABpex3vx2aZm.jpg?size=1852x1852&quality=95&type=album',
#                                                                'width': 1852},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/Tsysrq3Y-zSkjevVBt3OyVJUtBmMLUw0xhlJ36IU-CoWKRSwRwuSmJjUVL1rw6hEPZe6eUNHE0dijBxzD7b-HlGK.jpg?size=130x130&quality=95&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/KpvTGfKsDWhTBEBx9j1qxQq9rUJ2th2QFGPFrZV3I-6OuMPV-eiH0AYx-SOVwjdMBlAHvihZnVEg0fID1JJJLYzN.jpg?size=200x200&quality=95&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/R-VSNxpPcp4LYPe3vpYJ1oECJSS_uUD9AYKVqtV1qRMG-W90YforxZdThnLMkjJpN-yTb4pkOSoXbf68QqkMekwG.jpg?size=320x320&quality=95&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-33.userapi.com/s/v1/ig2/sC4WRJ_JdOW666qMIn2-oQfLMQ5hq4L64DSAsiTE0ZoHapzBIYjcLL00nECgfyy8CGw5gZehcX86lDkgfDlExCmk.jpg?size=510x510&quality=95&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 330,
#                                       'groups_can_post': True},
#                          'date': 1649349732,
#                          'from_id': -22822305,
#                          'hash': 'WT2AC_dNJrLvQfjoMQ',
#                          'id': 1291831,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1554,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'platform': 'iphone', 'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 387, 'user_reposted': 0},
#                          'text': 'В VK Видео обновление для тех, кто не любит '
#                                  'ждать. Теперь смотреть новые ролики можно '
#                                  'без промедления — как только автор загрузил '
#                                  'их на платформу. Никакой долгой обработки: '
#                                  'например, видеофайл весом 1 Гбайт будет '
#                                  'доступен мгновенно. На других ресурсах '
#                                  'подготовка такого ролика занимает от 3 до 10 '
#                                  'минут. \n'
#                                  '\n'
#                                  'Секрет в технологии VK Видео, с которой '
#                                  'видеопоток обрабатывается посегментно в '
#                                  'режиме реального времени. В результате '
#                                  'начинать смотреть можно практически сразу, в '
#                                  'удобном формате и разрешении. \n'
#                                  '\n'
#                                  'Особенно полезным обновление будет для '
#                                  'авторов, которым важна каждая минута. '
#                                  'Например, новостным медиа: достаточно '
#                                  'отснять материал и загрузить его ВКонтакте, '
#                                  'и свежий сюжет сразу попадёт к подписчикам.',
#                          'views': {'count': 1233734}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'd152e471225c7a530f',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1648630509,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2238139992669&idx=0&type=39&tkn=h-tFKZCjsOKHv1moZR8woglxzPU&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456239598,
#                                                     'owner_id': -139533130,
#                                                     'photo_1280': 'https://sun9-5.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=1280x720&quality=96&sign=68b66066fbfc2016cbf42fc47ec28633&c_uniq_tag=5ta-irADHlhDJ2XyHG-7Zto1aI9ZsD17dJshysww2RY&type=video_thumb',
#                                                     'photo_130': 'https://sun9-5.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=39fe497c3ab4f040bbcc73f0f441205d&c_uniq_tag=hIAv1yFUpn9r_qo8BthRNc3A-cevMkbMCO_OPch7QOg&type=video_thumb',
#                                                     'photo_320': 'https://sun9-5.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=9773fba63f698c3ebea0e9024350af58&c_uniq_tag=chvD9WFMDo1mBwE6qHeUY5373-0lSYxZjl5c0Fvkn1g&type=video_thumb',
#                                                     'photo_800': 'https://sun9-5.userapi.com/impf/LRSuV1PIsw_t9TuUcKIvXQKXuSo-6TBJfZdsQg/I9Rv_DbvlRQ.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=ed7577955480c0d8c0cd6a50f46b65ee&c_uniq_tag=4-_zWmEATvr9Bwhiwes7xSgywKKUzdaYsGgOtksmuJg&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'Создавать '
#                                                              'истории — просто',
#                                                     'track_code': 'video_fe18440apYkYZsJWZWWNHEqjEmVzmMCdzyPH9_qHqZMuen6xPJKfrwdkwVoPZ4wVQKp_Zkau8q72Fv7P_vDI_0J6',
#                                                     'views': 593880,
#                                                     'width': 1920}},
#                                          {'type': 'video',
#                                           'video': {'access_key': '2016c91ffaa91419bb',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1648630835,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2250776906304&idx=0&type=39&tkn=smxQZQdK_2QJWyt_wnJEu5QM67k',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2250776906304&idx=0&type=39&tkn=smxQZQdK_2QJWyt_wnJEu5QM67k&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2250776906304&idx=0&type=39&tkn=smxQZQdK_2QJWyt_wnJEu5QM67k&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2250776906304&idx=0&type=39&tkn=smxQZQdK_2QJWyt_wnJEu5QM67k&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2250776906304&idx=0&type=39&tkn=smxQZQdK_2QJWyt_wnJEu5QM67k&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456239599,
#                                                     'owner_id': -139533130,
#                                                     'photo_1280': 'https://sun9-88.userapi.com/impf/sWithyTYhndz2y-3z0aelZA2QUEFSS9xM_i5dQ/6ikQyFvjTN0.jpg?size=1280x720&quality=96&sign=710dbd91993eee820552dfca966c593b&c_uniq_tag=AKuMv7yFpEYP-YppIdcboMqjpT5uTMSX2o1nDS0dPFs&type=video_thumb',
#                                                     'photo_130': 'https://sun9-88.userapi.com/impf/sWithyTYhndz2y-3z0aelZA2QUEFSS9xM_i5dQ/6ikQyFvjTN0.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=4cede7abf8d705ecf913f77f9a5b83b9&c_uniq_tag=G6COcSPJMtbZEJMfrQUGNSn1lSh5B_Fake1iXBcVeaI&type=video_thumb',
#                                                     'photo_320': 'https://sun9-88.userapi.com/impf/sWithyTYhndz2y-3z0aelZA2QUEFSS9xM_i5dQ/6ikQyFvjTN0.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=57105a25306a95a8d3a5b151773130cc&c_uniq_tag=N0vhu3fWM1yJePwWfIwU0E_CYisRu0m_eMWBtbo1p2Y&type=video_thumb',
#                                                     'photo_800': 'https://sun9-88.userapi.com/impf/sWithyTYhndz2y-3z0aelZA2QUEFSS9xM_i5dQ/6ikQyFvjTN0.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=e41a411bd4c12e3a5669049c796843f8&c_uniq_tag=WLMfHenaOtjLsed6uaJhRLW9CXTQMGEpg7gRzg8poXw&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'Сюжеты ВКонтакте',
#                                                     'track_code': 'video_bda080f7Am2AtevZ-dpNXfmNd2JDJszQqbHe2UOtfA3_8paf-244S5-36NWT2ExU84QaYXYQ_uOQhOfgR9odYZPy',
#                                                     'views': 589152,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 1081,
#                                       'groups_can_post': True},
#                          'date': 1648975800,
#                          'from_id': -22822305,
#                          'hash': 'P552aGW2T1znNxYCIA',
#                          'id': 1289927,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 950,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 281, 'user_reposted': 0},
#                          'text': 'Подсчитали: просмотры историй ВКонтакте '
#                                  'выросли на 123%. Поэтому для всех новичков '
#                                  'подготовили простую и понятную пошаговую '
#                                  '[https://vk.com/@vkstories-istorii-gaid|инструкцию].\n'
#                                  '\n'
#                                  'В статье объясняем, как создавать истории и '
#                                  'объединять их в сюжеты. А ещё — как снимать '
#                                  'клипы, вести прямой эфир, проводить опросы и '
#                                  'получать вопросы от подписчиков: '
#                                  'vk.com/@vkstories-istorii-gaid',
#                          'views': {'count': 1007606}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '12b20e600ca344e611',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 3,
#                                                     'date': 1648538727,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2224930884126&idx=0&type=39&tkn=ZTDqqPOW0f5NOjs2WR_-0-SwS2s',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2224930884126&idx=0&type=39&tkn=ZTDqqPOW0f5NOjs2WR_-0-SwS2s&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2224930884126&idx=0&type=39&tkn=ZTDqqPOW0f5NOjs2WR_-0-SwS2s&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2224930884126&idx=0&type=39&tkn=ZTDqqPOW0f5NOjs2WR_-0-SwS2s&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2224930884126&idx=0&type=39&tkn=ZTDqqPOW0f5NOjs2WR_-0-SwS2s&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456241751,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://sun9-31.userapi.com/impf/kyNxvw3A1sizizTAQ5IVHfVqcArhK5rJVGiI5w/izSML3-Sc-E.jpg?size=1280x720&quality=96&sign=f952f959023c6bd32eb5283ae7947290&c_uniq_tag=5yCY86tga_u2mWB7h0RKo-v3RieNmoi__EnnN-Ptt2k&type=video_thumb',
#                                                     'photo_130': 'https://sun9-31.userapi.com/impf/kyNxvw3A1sizizTAQ5IVHfVqcArhK5rJVGiI5w/izSML3-Sc-E.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=d50d5c868432375adc9e9daa5d5d10f6&c_uniq_tag=RlkNABIuahD7Jsw2PsMPa0xq8QQY9Tqo36PdZ1od4hs&type=video_thumb',
#                                                     'photo_320': 'https://sun9-31.userapi.com/impf/kyNxvw3A1sizizTAQ5IVHfVqcArhK5rJVGiI5w/izSML3-Sc-E.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=00ca350c297cbcd6242bdda354df4a1f&c_uniq_tag=6-Bz8a9wlGAM1FjTu_Vcd7lY6kZSOTJ3YdrkOKFaHKo&type=video_thumb',
#                                                     'photo_800': 'https://sun9-31.userapi.com/impf/kyNxvw3A1sizizTAQ5IVHfVqcArhK5rJVGiI5w/izSML3-Sc-E.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=bbded04c04bfd9d665071bafd24fbc77&c_uniq_tag=2EiPYSqegwo11HQP5zpRgfvVtv7k_RVTig6dMSyhaW4&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'Как пригласить '
#                                                              'друзей из списка '
#                                                              'контактов?',
#                                                     'track_code': 'video_a08a8a30ZAA0zmcVG60xFOg2FA4D37gmZcWuehi6XR4bcU_WIqFUISrMYHIYrTod6F0XOzXtjBdS8J9-b9sxchs',
#                                                     'views': 2827040,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 497,
#                                       'groups_can_post': True},
#                          'date': 1648885800,
#                          'from_id': -22822305,
#                          'hash': 'b5xTR-RYIlUnl-KX3A',
#                          'id': 1289547,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1710,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 393, 'user_reposted': 0},
#                          'text': 'В этом месяце пользователи ВКонтакте стали '
#                                  'добавляться в друзья на десятки миллионов '
#                                  'раз чаще. Количество новых дружб выросло на '
#                                  '250%.\n'
#                                  '\n'
#                                  'Чтобы пригласить своих друзей ВКонтакте, '
#                                  'нужно открыть мобильное приложение и '
#                                  'импортировать контакты из вашей телефонной '
#                                  'книги. Как это сделать, наглядно показываем '
#                                  'на видео.\n'
#                                  '\n'
#                                  'Вы также можете найти знакомого с помощью '
#                                  'поиска. Выберите страну и город, возраст '
#                                  'и/или учебное заведение, чтобы точно '
#                                  'отыскать того, кого нужно. Обратите '
#                                  'внимание: по номеру телефона найти '
#                                  'пользователя таким образом нельзя, даже если '
#                                  'он указал его в контактной информации.',
#                          'views': {'count': 2719499}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '26576241bea31ec2c4',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1648629533,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2337354484280&idx=0&type=39&tkn=4dbV9WKOgLK71easQhTISYTP17k',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2337354484280&idx=0&type=39&tkn=4dbV9WKOgLK71easQhTISYTP17k&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2337354484280&idx=0&type=39&tkn=4dbV9WKOgLK71easQhTISYTP17k&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2337354484280&idx=0&type=39&tkn=4dbV9WKOgLK71easQhTISYTP17k&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2337354484280&idx=0&type=39&tkn=4dbV9WKOgLK71easQhTISYTP17k&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456239309,
#                                                     'owner_id': -59800369,
#                                                     'photo_1280': 'https://sun9-69.userapi.com/impf/yi3_EkVgac7lMzdqvHrusW5JdIG8GEWw-SYvFg/YURlBbVUwic.jpg?size=1280x720&quality=96&sign=a9ab1d715c7fad0646a03b4abdea70e0&c_uniq_tag=_LzFTds7UMR65sS12ryfWgCkg98yCMQ2ob5DWkBxO6g&type=video_thumb',
#                                                     'photo_130': 'https://sun9-69.userapi.com/impf/yi3_EkVgac7lMzdqvHrusW5JdIG8GEWw-SYvFg/YURlBbVUwic.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=81fd2f1b6427c57241c950abe429f3c6&c_uniq_tag=lMbS78kv8dX9VaesAuXRGHOkQKNqWWnILM8DSW5wUdM&type=video_thumb',
#                                                     'photo_320': 'https://sun9-69.userapi.com/impf/yi3_EkVgac7lMzdqvHrusW5JdIG8GEWw-SYvFg/YURlBbVUwic.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=e2688bf49fcf0514f425dc51661e3080&c_uniq_tag=msVMV9Z1r1xJ0qQu0W1bXfBNA4agkL6A5Kv8uuMlCjs&type=video_thumb',
#                                                     'photo_800': 'https://sun9-69.userapi.com/impf/yi3_EkVgac7lMzdqvHrusW5JdIG8GEWw-SYvFg/YURlBbVUwic.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=d0292bea29132d1e6a5d54cb16191db9&c_uniq_tag=nrrKWrwUiTZRCa7J5w-P517EBTLKeIRpp_53SmnInAo&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'Как создать '
#                                                              'сообщество '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_3fb48217rtrq8SSxAUK8_savuf4F5HaBtUrIUiNAiksRgBYjEoae-_T0KNYAQLfxzca9yzPWRbiGevFWVCHmJxE',
#                                                     'views': 761672,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 155,
#                                       'groups_can_post': True},
#                          'date': 1648803000,
#                          'from_id': -22822305,
#                          'hash': 'hrf3WrF0ffsdvK6r3g',
# ...
#                          'text': 'Кто мы такие, чтобы сопротивляться всеобщим '
#                                  'итогам года? Подводим свои. \n'
#                                  '\n'
#                                  'В этом году мы запустили больше 200 крупных '
#                                  'новинок — всё, чтобы Вам нравилось делиться '
#                                  'моментами жизни, читать материалы друзей и '
#                                  'других авторов, решать повседневные задачи и '
#                                  'развивать своё дело в VK. \n'
#                                  '\n'
#                                  'Какими вышли результаты — рассказываем в '
#                                  'блоге: vk.com/blog/vk-results-2019',
#                          'views': {'count': 1521271}},
#                         {'attachments': [{'link': {'button': {'action': {'type': 'open_url',
#                                                                          'url': 'https://vk.com/app7245724#utm_source=vk&utm_medium=vk_community&utm_campaign=NewYearCalendar2020&utm_content=team'},
#                                                               'title': 'Launch'},
#                                                    'caption': 'Application',
#                                                    'description': 'Выполняйте '
#                                                                   'тематические '
#                                                                   'задания '
#                                                                   'каждый\xa0'
#                                                                   'день, '
#                                                                   'получайте\xa0'
#                                                                   'баллы и\xa0'
#                                                                   'соревнуйтесь\xa0'
#                                                                   'с\xa0'
#                                                                   'друзьями',
#                                                    'photo': {'album_id': -28,
#                                                              'date': 1577357489,
#                                                              'id': 457286631,
#                                                              'owner_id': 2000030043,
#                                                              'sizes': [{'height': 480,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun9-80.userapi.com/impg/4QkkGCCK0WM2vz2BwpckMPvTurX5riTIFKUQiA/IvMD90B9wOY.jpg?size=1074x480&quality=96&sign=81892d8b89cdff1e0c1f627edb747f0f&c_uniq_tag=_oXJdOEkmBFbC93xgKqZW6xEyOH36a2nJ5IiklKEJ1Q&type=share',
#                                                                         'width': 1074},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun9-80.userapi.com/impg/4QkkGCCK0WM2vz2BwpckMPvTurX5riTIFKUQiA/IvMD90B9wOY.jpg?size=537x240&quality=96&sign=d88ab3532764c9e96d83a1800a1222eb&c_uniq_tag=g1mcSGuKpzWtB28jmpMTadZ9SDQFE7HwpaKx6IqbVBc&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 73,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun9-80.userapi.com/impg/4QkkGCCK0WM2vz2BwpckMPvTurX5riTIFKUQiA/IvMD90B9wOY.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=b8eac259cd6542d5daf3c72fc66b2fbe&c_uniq_tag=NAPVT3EbFVkY1kjSmHDzDmAbkgTF-u1nSUTVR7foNgg&type=share',
#                                                                         'width': 130},
#                                                                        {'height': 146,
#                                                                         'type': 'p',
#                                                                         'url': 'https://sun9-80.userapi.com/impg/4QkkGCCK0WM2vz2BwpckMPvTurX5riTIFKUQiA/IvMD90B9wOY.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=2658304e23ebf0dc00a8fd86cee5d3f8&c_uniq_tag=P9cV3KNWHyx3i7o_2xMIuQKWuSAJvgTFy42MMkC1ODk&type=share',
#                                                                         'width': 260},
#                                                                        {'height': 42,
#                                                                         'type': 's',
#                                                                         'url': 'https://sun9-80.userapi.com/impg/4QkkGCCK0WM2vz2BwpckMPvTurX5riTIFKUQiA/IvMD90B9wOY.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=4bd1b67bca6003d5b6270f3162761b07&c_uniq_tag=zA3_WAvNvSki5mnEsMZhAY6AzWyuJY2lNDK27cAuZ6A&type=share',
#                                                                         'width': 75},
#                                                                        {'height': 84,
#                                                                         'type': 'x',
#                                                                         'url': 'https://sun9-80.userapi.com/impg/4QkkGCCK0WM2vz2BwpckMPvTurX5riTIFKUQiA/IvMD90B9wOY.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=c004fec5267fde316dfe2bf3f198d968&c_uniq_tag=Y8OgTAeHW2fupwApwtHWuo_6yF6pprXgM2Hz8VtNEoI&type=share',
#                                                                         'width': 150}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Новогодний '
#                                                             'календарь',
#                                                    'url': 'https://vk.com/app7245724#utm_source=vk&utm_medium=vk_community&utm_campaign=NewYearCalendar2020&utm_content=team'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 790,
#                                       'groups_can_post': True},
#                          'date': 1577361839,
#                          'from_id': -22822305,
#                          'hash': 'LtVlpBAsFAiAQzLfNA',
#                          'id': 1011358,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 3059,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 230, 'user_reposted': 0},
#                          'text': 'Новый год уже рядом, а праздничного '
#                                  'настроения всё нет? Найти его и провести '
#                                  'выходные насыщенно поможет Новогодний '
#                                  'календарь: vk.cc/a9WTx1\n'
#                                  '\n'
#                                  'Каждую полночь в нём будут появляться '
#                                  'тематические задания. Выполняйте их — и '
#                                  'сможете насладиться новогодней атмосферой по '
#                                  'полной: окажетесь в красивых зимних местах, '
#                                  'встретитесь с близкими и хорошо '
#                                  'повеселитесь.\n'
#                                  '\n'
#                                  'Публикуйте все эти моменты в историях — так '
#                                  'Вы не только сохраните их на память, но и '
#                                  'получите баллы. Рейтинг покажет, кто из '
#                                  'Ваших друзей справляется с новогодним '
#                                  'квестом лучше всех.\n'
#                                  '\n'
#                                  'Присоединяйтесь к игре и делайте атмосферу '
#                                  'вокруг по-настоящему праздничной!',
#                          'views': {'count': 1053897}},
#                         {'attachments': [{'photo': {'access_key': '04e8cf7ef1560cf323',
#                                                     'album_id': -7,
#                                                     'date': 1577277853,
#                                                     'id': 457304860,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1010619,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/QjcmAJizxK7ZasgczeuTREAYewsoxQYnzXjmjPXJG581FnN7RLmBufNfw0MC7oLm3yeUjFL10WfORgZB6oknYUBn.jpg?size=130x130&quality=96&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/QjcmAJizxK7ZasgczeuTREAYewsoxQYnzXjmjPXJG581FnN7RLmBufNfw0MC7oLm3yeUjFL10WfORgZB6oknYUBn.jpg?size=130x130&quality=96&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/0DsQ-pyNUVriPXe2ToIPbPh7qSwDFYS1gXuZEVioCSU9m3Pn47vlRBpk8Z8XcVkfehVXpfdoTH2xCZjYPmMMEMHz.jpg?size=200x200&quality=96&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/eK3kdKAarmNU-vrb-mZv3mBc4hbqzPe5C_UjjrjvZAMHjieQiwKWMkHy0WO8aLD6tfIUdB1nzcD7QjAF3RB5V7My.jpg?size=320x320&quality=96&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/CuCt2WnwCKlnXeRuwMajKZKVNh60jJ7v3AbeCJzCy_-2hqnyVRguO9l37fYuaY5jFwO8-jKBMJwM7YKOgF9BdEgq.jpg?size=510x510&quality=96&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/n3s7OzKk1XjBWH_5xzE-x0V3g9czJ0-iZn2tjKX4omxVsfwXg5629VHQwcME4lUiAiXN7uyDhT0j-hoL3loRTlL5.jpg?size=75x75&quality=96&type=album',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/pKS_Y6XMIFvjd1itGzM0SeImPMCUYm-forRGecrB4fqm1WGPeQqlb7fp6VGBMujncn2hpHunvzC2GqqfIL62eaRO.jpg?size=604x604&quality=96&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/tD7Ykpy-vpy8lftd7-eG2ZdWTza7BYgpqFm8N6bEtBdmmvTqcCQ9--AmCrtIeBGhVOrqEiGtMiI4m26S0VqaKMes.jpg?size=807x807&quality=96&type=album',
#                                                                'width': 807},
#                                                               {'height': 1000,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-82.userapi.com/s/v1/ig2/C-ZZnYPZb_aN3oLSzACJpUmGV2FoDLP5cZcWTr15v4WDUaT-2F6LYw-8SNBCofYw6a6CLTposgTwTsMvgKLhD3JD.jpg?size=1000x1000&quality=96&type=album',
#                                                                'width': 1000}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 954,
#                                       'groups_can_post': True},
#                          'date': 1577277874,
#                          'from_id': -22822305,
#                          'hash': '3uusIDFEoWEmxwDq3w',
#                          'id': 1010619,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 7827,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 287, 'user_reposted': 0},
#                          'text': 'В Новый год самое приятное — творить чудеса. '
#                                  'Нашей совместной магии хватит, чтобы помочь '
#                                  'кому-то выздороветь и найти семью, накормить '
#                                  'бездомных животных. Разве не чудо? И сделать '
#                                  'это проще простого. Достаточно отправить '
#                                  'благотворительный подарок. \n'
#                                  '\n'
#                                  'Зайдите на страницу любого человека, нажмите '
#                                  'на знак подарка и выберите анимированный '
#                                  'сюрприз с бурундуком Квипом — в этом году он '
#                                  'учил нас основам русского жестового языка. '
#                                  'Этот подарок стоит 21 рубль, как и все '
#                                  'другие, но по сути гораздо ценнее: все '
#                                  'средства от его продажи пойдут в '
#                                  'благотворительные фонды «[club37437056|Живи, '
#                                  'малыш]», «[club39873171|Дети ждут]» и '
#                                  '«[club36918666|Фонд помощи бездомным '
#                                  'животным „РЭЙ“]». \n'
#                                  '\n'
#                                  'Вы можете отправить благотворительный '
#                                  'подарок сколько угодно раз. Порадуйте '
#                                  'близких и позаботьтесь о тех, кому нужна '
#                                  'помощь.',
#                          'views': {'count': 1566707}}]}}

# %% [markdown]
# Анализируя ответ, понимаем, что по ключу count можно найти общее количество сообщений в новостной ленте, а по ключу items — сами сообщения.

# %%
# Посмотрим на информацию об отдельном сообщении:
response.json()['response']['items'][0]
# Out:
# {'id': 1294102,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1650036838,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'Представляем мобильное приложение VK Звонков — со всеми функциями для безлимитных онлайн-конференций. Оно уже доступно в App Store (vk.cc/ccNmFQ) и Google Play (vk.cc/ccNmMx). А в браузере попробуйте веб-версию: calls.vk.com. \n\nПриложение полностью бесплатное, и все возможности VK Звонков — в быстром доступе. Подключиться к конференции по ссылке можно даже без профиля. Время разговора и количество участников не ограничены: собирайте друзей, подписчиков, слушателей онлайн-курса или всю команду большого проекта.\n\nПланируете встречи заранее? Скоро это можно будет удобно делать в VK Звонках. Можно будет создать конференцию, поставить напоминание в календаре и отправить ссылку участникам — по почте или в любом мессенджере. В нужное время звонок станет активным, и собеседники смогут присоединиться. Для регулярных встреч можно сделать звонок повторяющимся. \n\nЗвонить и принимать вызовы всё так же можно на других платформах: в приложении и веб-версии ВКонтакте, десктопном приложении VK Звонков.',
#  'attachments': [{'type': 'video',
#    'video': {'access_key': '5bd99da508c4b69bd5',
#     'can_comment': 0,
#     'can_like': 1,
#     'can_repost': 1,
#     'can_subscribe': 1,
#     'can_add_to_faves': 1,
#     'can_add': 1,
#     'comments': 0,
#     'date': 1650036655,
#     'description': '',
#     'duration': 30,
#     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_s',
#     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_l',
#     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_x',
#     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=15&type=39&tkn=7-k3eIDfQhpRq7nko5LWYBCFHTI&fn=vid_w',
#     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_sm',
#     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_d',
#     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_md',
#     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM&fn=vid_f',
#     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2382458915369&idx=0&type=39&tkn=vge7zyIArOd1dYgALRHy3Z5NCrM',
#     'width': 1920,
#     'height': 1080,
#     'id': 456241782,
#     'owner_id': -22822305,
#     'title': 'VK Звонки',
#     'track_code': 'video_8f278775tb2G3mpQ4486jmT3jUo6308j2Ity8OmZKilwvPf_V22FnJjcbTfgjzCKYJiLfwztexLvs0D0nvhGRXA',
#     'repeat': 1,
#     'views': 262995}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'can_post': 1, 'count': 377, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 865, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 282, 'user_reposted': 0},
#  'views': {'count': 278826},
#  'hash': 'gVQZBtobU3LADAIKew'}

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.
# ***
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'Аудитория ВКонтакте растёт: в ': [403, 1128, 268, 1648644620],
#  'В VK Видео обновление для тех,': [330, 1554, 387, 1649349732],
#  'В VK Видео — обновление для лю': [204, 852, 208, 1649929834],
#  'В мультивселенной ВКонтакте от': [1422, 4966, 1276, 1649757486],
#  'В этом месяце пользователи ВКо': [497, 1710, 393, 1648885800],
#  'Весной пользователи стали созд': [155, 740, 180, 1648803000],
#  'Запустили приложение VK Видео ': [547, 1415, 539, 1648119076],
#  'Подсчитали: просмотры историй ': [1081, 950, 281, 1648975800],
#  'Представляем мобильное приложе': [377, 865, 282, 1650036838],
#  'Что посмотреть ВКонтакте? [htt': [386, 528, 90, 1648715757]}

# %% [markdown]
# Полный список методов ВКонтакте можно посмотреть в [**документации**](https://vk.com/dev/methods).

# %% [markdown]
# ##### **ДРУГИЕ API**
# ***
# Вы познакомились с интерфейсами прикладного программирования — **API** (на примере API социальной сети ВКонтакте).
#
# API для разработчиков предоставляют и многие другие платформы. Вот список, пожалуй, самых популярных из них:
#
# * [Google Maps API](https://developers.google.com/maps/)
# * [YouTube API](https://developers.google.com/youtube/)
# * [Twitter API](https://dev.twitter.com/overview/documentation)
# * [Facebook API](https://developers.facebook.com/docs/)
#
# Информацию о сторонних API можно найти в [каталоге Web API](https://www.programmableweb.com/category/all/apis). Также можно воспользоваться интернет-поиском, указав в строке поиска, например, «курсы валют API» или «прогноз погоды api», — среди первых результатов выдачи чаще всего с лёгкостью можно найти ссылки на необходимый функционал.
